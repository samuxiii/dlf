# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = '/data/small_vocab_en'
target_path = '/data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source_id_text = []
    for sentence in source_text.split("\n"):
        source_id_text.append([source_vocab_to_int[word] for word in sentence.split()])

    target_id_text = []
    for sentence in target_text.split("\n"):
        target_id_text.append([target_vocab_to_int[word] for word in sentence.split()] + [target_vocab_to_int['<EOS>']])

    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    
    inputs = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32)
    kp = tf.placeholder(tf.float32, name='keep_prob')
    t_seq_length = tf.placeholder(tf.int32, [None], name='target_sequence_length')
    max_t_length = tf.reduce_max(t_seq_length, name='max_target_len')
    s_seq_length = tf.placeholder(tf.int32, [None], name='source_sequence_length')
    
    return inputs, targets, lr, kp, t_seq_length, max_t_length, s_seq_length

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    data_without_end = tf.strided_slice(target_data, [0,0], [batch_size, -1], [1,1])
    go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    data = tf.concat( [go, data_without_end], 1)
    
    return data

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    
    input_embed = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
    def cell():
        #!!!!! define weights initializer could improve the results...
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        drop = tf.contrib.rnn.DropoutWrapper(lstm, keep_prob, seed=42)
        return drop
    
    stacked_lstm = tf.contrib.rnn.MultiRNNCell([cell() for _ in range(num_layers)])     
    output, state = tf.nn.dynamic_rnn(stacked_lstm, 
                                      input_embed, sequence_length=source_sequence_length, 
                                      dtype=tf.float32)
    
    return output, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """

    training_helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    
    #regularize using dropout
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
    basic_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, training_helper, encoder_state, output_layer)
    
    outputs, _ = tf.contrib.seq2seq.dynamic_decode(basic_decoder, impute_finished = True, maximum_iterations=max_summary_length)
        
    return outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """

    #create vector of start tokens
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size])
    greedy_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, 
                                                             start_tokens, 
                                                             end_of_sequence_id)
    
    #apply dropout
    drop_dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
    
    basic_decoder = tf.contrib.seq2seq.BasicDecoder(drop_dec_cell, greedy_helper, encoder_state, output_layer)
    outputs, _ = tf.contrib.seq2seq.dynamic_decode(basic_decoder, 
                                                   impute_finished = True, 
                                                   maximum_iterations=max_target_sequence_length)
    
    
    return outputs

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    #embed
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    #lstm
    def cell():
        #!!!!! define weights initializer could improve the results...
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        #drop = tf.contrib.rnn.DropoutWrapper(lstm, keep_prob, seed=42)
        return lstm
    
    stacked_lstm = tf.contrib.rnn.MultiRNNCell([cell() for _ in range(num_layers)])
    
    #output layer
    stddev = 1/np.sqrt(decoding_embedding_size)
    kinit = tf.truncated_normal_initializer(stddev=stddev, seed=42)
    output_layer = Dense(target_vocab_size, kernel_initializer = kinit)
    
    
    #decoding layer traing
    with tf.variable_scope("decode"):
        training_decoder = decoding_layer_train(encoder_state, 
                                                 stacked_lstm, 
                                                 dec_embed_input, 
                                                 target_sequence_length, 
                                                 max_target_sequence_length, 
                                                 output_layer, 
                                                 keep_prob)
    
    #decoding layer inference
    with tf.variable_scope("decode", reuse=True):
        inference_decoder = decoding_layer_infer(encoder_state, 
                                                 stacked_lstm, 
                                                 dec_embeddings, 
                                                 target_vocab_to_int['<GO>'],#start_of_sequence_id, 
                                                 target_vocab_to_int['<EOS>'],#end_of_sequence_id, 
                                                 max_target_sequence_length, 
                                                 target_vocab_size, 
                                                 output_layer, 
                                                 batch_size, 
                                                 keep_prob)
    
    return training_decoder, inference_decoder



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """

    #we have to ignore the output, only we need the encoder state
    _, enc_state = encoding_layer(input_data, 
                                   rnn_size, 
                                   num_layers, 
                                   keep_prob,  
                                   source_sequence_length, 
                                   source_vocab_size, 
                                   enc_embedding_size)

    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    return decoding_layer(dec_input, 
                          enc_state, 
                          target_sequence_length, 
                          max_target_sentence_length, 
                          rnn_size, num_layers, 
                          target_vocab_to_int, 
                          target_vocab_size, 
                          batch_size, 
                          keep_prob, 
                          dec_embedding_size)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 1
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.7
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2533, Validation Accuracy: 0.3587, Loss: 3.3369
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3191, Validation Accuracy: 0.3899, Loss: 2.5893
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3816, Validation Accuracy: 0.4322, Loss: 2.1682
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.3836, Validation Accuracy: 0.4371, Loss: 1.7114
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.4520, Validation Accuracy: 0.5231, Loss: 1.3657
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4929, Validation Accuracy: 0.5202, Loss: 1.0591
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.4893, Validation Accuracy: 0.5344, Loss: 0.9708
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5330, Loss: 0.8670
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5607, Loss: 0.8604
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.5891, Loss: 0.7799
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.6223, Validation Accuracy: 0.5902, Loss: 0.6827
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.5895, Validation Accuracy: 0.6023, Loss: 0.7055
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.5960, Validation Accuracy: 0.5945, Loss: 0.6042
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.5868, Validation Accuracy: 0.6303, Loss: 0.6405
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.6384, Validation Accuracy: 0.6644, Loss: 0.5664
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.6535, Validation Accuracy: 0.6477, Loss: 0.5406
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.6152, Validation Accuracy: 0.6566, Loss: 0.5623
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.6430, Validation Accuracy: 0.6552, Loss: 0.5093
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.7070, Validation Accuracy: 0.6896, Loss: 0.4791
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.6820, Validation Accuracy: 0.6864, Loss: 0.4715
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.6935, Validation Accuracy: 0.7042, Loss: 0.4349
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.7023, Validation Accuracy: 0.7116, Loss: 0.4227
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.7124, Validation Accuracy: 0.7092, Loss: 0.3945
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.7348, Validation Accuracy: 0.7120, Loss: 0.3591
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.7333, Validation Accuracy: 0.7227, Loss: 0.3287
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.7772, Validation Accuracy: 0.7358, Loss: 0.3138
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.7098, Validation Accuracy: 0.7749, Loss: 0.3385
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.7727, Validation Accuracy: 0.7525, Loss: 0.3188
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.7590, Validation Accuracy: 0.7837, Loss: 0.3185
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.7722, Validation Accuracy: 0.7461, Loss: 0.2832
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.7625, Validation Accuracy: 0.7773, Loss: 0.2883
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.7691, Validation Accuracy: 0.7734, Loss: 0.2642
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.8137, Validation Accuracy: 0.7912, Loss: 0.2528
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.8166, Validation Accuracy: 0.7486, Loss: 0.2477
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.8016, Validation Accuracy: 0.7670, Loss: 0.2514
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.8383, Validation Accuracy: 0.7905, Loss: 0.2305
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.8296, Validation Accuracy: 0.7852, Loss: 0.2068
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.7788, Loss: 0.2128
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.8008, Validation Accuracy: 0.7848, Loss: 0.2249
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.8422, Validation Accuracy: 0.8004, Loss: 0.2104
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.8117, Validation Accuracy: 0.8050, Loss: 0.2088
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.8555, Validation Accuracy: 0.8374, Loss: 0.1652
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.8348, Validation Accuracy: 0.8207, Loss: 0.1679
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.8449, Validation Accuracy: 0.8214, Loss: 0.1915
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.8398, Validation Accuracy: 0.7610, Loss: 0.1640
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.8410, Validation Accuracy: 0.8395, Loss: 0.1721
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.8423, Loss: 0.1586
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.8651, Validation Accuracy: 0.8473, Loss: 0.1440
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.8473, Validation Accuracy: 0.8477, Loss: 0.1414
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.8691, Validation Accuracy: 0.8494, Loss: 0.1270
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.8250, Validation Accuracy: 0.8597, Loss: 0.1517
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.8969, Validation Accuracy: 0.8565, Loss: 0.1163
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.8414, Validation Accuracy: 0.8406, Loss: 0.1446
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.8680, Validation Accuracy: 0.8427, Loss: 0.1158
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.8535, Validation Accuracy: 0.8675, Loss: 0.1311
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8402, Loss: 0.1079
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.8787, Validation Accuracy: 0.8558, Loss: 0.1258
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.8869, Validation Accuracy: 0.8935, Loss: 0.0982
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.8643, Validation Accuracy: 0.8686, Loss: 0.1260
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.8765, Validation Accuracy: 0.8675, Loss: 0.1107
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.8873, Validation Accuracy: 0.8817, Loss: 0.1055
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.9008, Validation Accuracy: 0.8732, Loss: 0.0983
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.8938, Validation Accuracy: 0.8704, Loss: 0.1042
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.8940, Validation Accuracy: 0.8800, Loss: 0.0995
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.8922, Validation Accuracy: 0.8668, Loss: 0.1075
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.8945, Validation Accuracy: 0.8778, Loss: 0.0961
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.8814, Validation Accuracy: 0.8601, Loss: 0.1028
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.8728, Validation Accuracy: 0.8800, Loss: 0.0948
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8888, Loss: 0.0911
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8732, Loss: 0.0761
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.8857, Loss: 0.0746
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.8717, Validation Accuracy: 0.8839, Loss: 0.0892
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.8881, Loss: 0.0966
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.8810, Loss: 0.0740
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.9137, Loss: 0.0688
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.8957, Validation Accuracy: 0.8920, Loss: 0.0853
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.8865, Validation Accuracy: 0.8896, Loss: 0.0743
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.8621, Validation Accuracy: 0.8952, Loss: 0.1091
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.8395, Validation Accuracy: 0.8860, Loss: 0.0840
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.8762, Validation Accuracy: 0.8864, Loss: 0.0912
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.9010, Validation Accuracy: 0.8935, Loss: 0.0606
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8793, Loss: 0.0773
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8970, Loss: 0.0840
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.8853, Loss: 0.0633
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.8531, Validation Accuracy: 0.9073, Loss: 0.1043
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.9052, Loss: 0.0744
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.9124, Validation Accuracy: 0.9055, Loss: 0.0623
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9041, Loss: 0.0700
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.8867, Loss: 0.0702
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.8984, Loss: 0.0782
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9308, Loss: 0.0677
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8974, Loss: 0.0754
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8757, Loss: 0.0592
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.8793, Loss: 0.0650
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.9096, Validation Accuracy: 0.8938, Loss: 0.0675
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.9025, Validation Accuracy: 0.8793, Loss: 0.0612
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.8928, Loss: 0.0747
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.8782, Loss: 0.0622
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.9021, Validation Accuracy: 0.8885, Loss: 0.0746
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8867, Loss: 0.0617
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9094, Loss: 0.0598
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9116, Loss: 0.0483
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.9144, Loss: 0.0604
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.9252, Validation Accuracy: 0.9094, Loss: 0.0652
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8906, Loss: 0.0529
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.9016, Loss: 0.0522
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.8963, Loss: 0.0535
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.9322, Validation Accuracy: 0.8963, Loss: 0.0589
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9052, Loss: 0.0448
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9148, Loss: 0.0507
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.8949, Loss: 0.0528
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9112, Loss: 0.0574
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9038, Loss: 0.0465
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.9256, Validation Accuracy: 0.9062, Loss: 0.0641
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9158, Loss: 0.0532
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9141, Loss: 0.0500
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.8952, Loss: 0.0546
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9134, Loss: 0.0434
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9176, Loss: 0.0508
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9062, Loss: 0.0478
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.9280, Validation Accuracy: 0.9134, Loss: 0.0533
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.9442, Validation Accuracy: 0.9176, Loss: 0.0521
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9396, Loss: 0.0369
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9119, Loss: 0.0519
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9176, Loss: 0.0445
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9197, Loss: 0.0487
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9208, Loss: 0.0517
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.8878, Loss: 0.0601
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.9400, Validation Accuracy: 0.9251, Loss: 0.0519
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.9048, Validation Accuracy: 0.8963, Loss: 0.0527
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9279, Loss: 0.0425
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.9013, Validation Accuracy: 0.9272, Loss: 0.0460
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9197, Loss: 0.0436
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9205, Loss: 0.0568
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.8934, Validation Accuracy: 0.9222, Loss: 0.0608
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.9251, Loss: 0.0586
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.9126, Loss: 0.0483
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9070, Loss: 0.0517
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9194, Loss: 0.0541
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.9144, Loss: 0.0530
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.9424, Validation Accuracy: 0.9002, Loss: 0.0463
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9119, Loss: 0.0453
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9215, Loss: 0.0342
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.9583, Validation Accuracy: 0.8857, Loss: 0.0448
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9247, Loss: 0.0455
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.9329, Loss: 0.0616
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.8864, Loss: 0.0531
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9268, Loss: 0.0554
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9276, Loss: 0.0313
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9162, Loss: 0.0358
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9059, Loss: 0.0517
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9084, Loss: 0.0462
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.8949, Loss: 0.0558
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.8949, Loss: 0.0417
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.9280, Validation Accuracy: 0.9094, Loss: 0.0415
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.8999, Loss: 0.0469
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9144, Loss: 0.0361
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9073, Loss: 0.0411
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.9442, Validation Accuracy: 0.9073, Loss: 0.0351
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.9105, Loss: 0.0525
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9038, Loss: 0.0358
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.8949, Loss: 0.0416
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.9205, Loss: 0.0427
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8917, Loss: 0.0500
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.9464, Validation Accuracy: 0.9332, Loss: 0.0355
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.9112, Validation Accuracy: 0.9169, Loss: 0.0524
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.9251, Loss: 0.0586
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.9474, Validation Accuracy: 0.9325, Loss: 0.0520
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9134, Loss: 0.0456
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9379, Loss: 0.0470
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.9405, Validation Accuracy: 0.9297, Loss: 0.0372
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9205, Loss: 0.0451
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9180, Loss: 0.0431
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.9080, Loss: 0.0482
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9165, Loss: 0.0377
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9244, Loss: 0.0419
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9322, Loss: 0.0343
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9382, Loss: 0.0403
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.9361, Loss: 0.0407
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9343, Loss: 0.0493
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9364, Loss: 0.0356
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9283, Loss: 0.0350
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9336, Loss: 0.0466
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.9360, Validation Accuracy: 0.9403, Loss: 0.0338
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.9090, Validation Accuracy: 0.9542, Loss: 0.0696
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.9428, Loss: 0.0499
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.9478, Loss: 0.0562
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.9118, Validation Accuracy: 0.9343, Loss: 0.0354
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9308, Loss: 0.0391
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.8844, Validation Accuracy: 0.9023, Loss: 0.0570
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9425, Loss: 0.0338
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.9085, Validation Accuracy: 0.9283, Loss: 0.0691
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.9446, Loss: 0.0479
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9286, Loss: 0.0356
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9315, Loss: 0.0445
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.9304, Validation Accuracy: 0.9094, Loss: 0.0374
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9403, Loss: 0.0492
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9386, Loss: 0.0457
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.9117, Validation Accuracy: 0.9229, Loss: 0.0442
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9173, Loss: 0.0356
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9208, Loss: 0.0381
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9261, Loss: 0.0340
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.9464, Validation Accuracy: 0.9105, Loss: 0.0342
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9151, Loss: 0.0450
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9300, Loss: 0.0481
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9094, Loss: 0.0435
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.9350, Loss: 0.0421
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9162, Loss: 0.0322
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9208, Loss: 0.0337
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9464, Loss: 0.0433
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9286, Loss: 0.0442
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9311, Loss: 0.0344
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9297, Loss: 0.0410
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9283, Loss: 0.0379
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9254, Loss: 0.0488
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9190, Loss: 0.0325
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9521, Loss: 0.0361
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9208, Loss: 0.0376
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9428, Loss: 0.0383
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9112, Loss: 0.0278
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.9264, Validation Accuracy: 0.9453, Loss: 0.0447
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9496, Loss: 0.0374
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9361, Loss: 0.0322
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9538, Loss: 0.0380
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9371, Loss: 0.0328
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9418, Loss: 0.0395
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.9546, Validation Accuracy: 0.9457, Loss: 0.0382
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9148, Loss: 0.0374
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9247, Loss: 0.0394
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9389, Loss: 0.0271
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9329, Loss: 0.0352
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9460, Loss: 0.0303
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9464, Loss: 0.0308
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9300, Loss: 0.0348
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.9475, Validation Accuracy: 0.9201, Loss: 0.0328
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.9519, Validation Accuracy: 0.9293, Loss: 0.0355
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.9353, Validation Accuracy: 0.9169, Loss: 0.0355
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9141, Loss: 0.0314
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.9283, Validation Accuracy: 0.9371, Loss: 0.0362
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.9187, Loss: 0.0308
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9407, Loss: 0.0463
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.9023, Loss: 0.0486
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9460, Loss: 0.0514
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9237, Loss: 0.0348
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9304, Loss: 0.0432
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9403, Loss: 0.0402
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9126, Loss: 0.0379
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9511, Validation Accuracy: 0.9237, Loss: 0.0359
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9183, Loss: 0.0317
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9357, Loss: 0.0327
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.9639, Validation Accuracy: 0.9379, Loss: 0.0331
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9496, Loss: 0.0292
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9510, Loss: 0.0444
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9315, Loss: 0.0422
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.9317, Validation Accuracy: 0.9311, Loss: 0.0401
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9485, Loss: 0.0309
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9308, Loss: 0.0309
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9251, Loss: 0.0409
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9336, Loss: 0.0350
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9261, Loss: 0.0381
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9201, Loss: 0.0364
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9286, Loss: 0.0397
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9318, Loss: 0.0344
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9411, Loss: 0.0303
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9482, Loss: 0.0374
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.9706, Validation Accuracy: 0.9183, Loss: 0.0329
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9357, Loss: 0.0425
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9144, Loss: 0.0294
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9102, Loss: 0.0360
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9112, Loss: 0.0281
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.8949, Loss: 0.0504
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9407, Loss: 0.0319
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9318, Loss: 0.0402
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.9368, Loss: 0.0456
# Epoch   2 Batch  610/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9393, Loss: 0.0347
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9265, Loss: 0.0297
# Epoch   2 Batch  630/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9297, Loss: 0.0370
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9389, Loss: 0.0336
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9393, Loss: 0.0364
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9268, Loss: 0.0281
# Epoch   2 Batch  670/1077 - Train Accuracy: 0.9460, Validation Accuracy: 0.9304, Loss: 0.0338
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9165, Loss: 0.0309
# Epoch   2 Batch  690/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9375, Loss: 0.0371
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9343, Loss: 0.0279
# Epoch   2 Batch  710/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9339, Loss: 0.0298
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9564, Validation Accuracy: 0.9549, Loss: 0.0311
# Epoch   2 Batch  730/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9318, Loss: 0.0395
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9116, Loss: 0.0299
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9279, Loss: 0.0353
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9435, Loss: 0.0416
# Epoch   2 Batch  770/1077 - Train Accuracy: 0.9349, Validation Accuracy: 0.9364, Loss: 0.0260
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.9418, Loss: 0.0480
# Epoch   2 Batch  790/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.9553, Loss: 0.0399
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9485, Loss: 0.0423
# Epoch   2 Batch  810/1077 - Train Accuracy: 0.9509, Validation Accuracy: 0.9478, Loss: 0.0283
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9350, Loss: 0.0371
# Epoch   2 Batch  830/1077 - Train Accuracy: 0.8879, Validation Accuracy: 0.9290, Loss: 0.0497
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9528, Loss: 0.0402
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9471, Loss: 0.0612
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9407, Loss: 0.0407
# Epoch   2 Batch  870/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9411, Loss: 0.0348
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9442, Loss: 0.0405
# Epoch   2 Batch  890/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9165, Loss: 0.0396
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9361, Loss: 0.0407
# Epoch   2 Batch  910/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9411, Loss: 0.0383
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9297, Loss: 0.0351
# Epoch   2 Batch  930/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9428, Loss: 0.0317
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9453, Loss: 0.0270
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.9435, Validation Accuracy: 0.9219, Loss: 0.0312
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9472, Validation Accuracy: 0.9318, Loss: 0.0341
# Epoch   2 Batch  970/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9517, Loss: 0.0373
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9421, Loss: 0.0393
# Epoch   2 Batch  990/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9272, Loss: 0.0395
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9300, Loss: 0.0355
# Epoch   2 Batch 1010/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9318, Loss: 0.0303
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9205, Loss: 0.0275
# Epoch   2 Batch 1030/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9311, Loss: 0.0328
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9318, Loss: 0.0397
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9183, Loss: 0.0319
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9336, Loss: 0.0357
# Epoch   2 Batch 1070/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9371, Loss: 0.0376
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in (sentence.lower()).split()]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [195, 10, 78, 147, 182, 227, 217]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [7, 297, 225, 143, 294, 256, 295, 176, 1]
#   French Words: il a conduit un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
